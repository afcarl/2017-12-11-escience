# %%
a_third = 0.333

# %%
print("Hello everyone!")
# Out:
# Hello everyone!

# %%
a = 42

# %% [markdown]
# # This is my title
#
# [This](http://escience.washington.edu) is a link
#
# * Bullet 1
# * Bullet 2

# %%
b = a * 2

# %%
print(b)
# Out:
# 84

# %%
print(a)
print(b * 2)
# Out:
# 42
# 168

# %% [markdown]
# # Let's talk about string variables
#
# Strings are useful, because we use them in language

# %%
first_name = "Ariel"

# %%
print(first_name)
# Out:
# Ariel

# %%
first_name
# Out:
# 'Ariel'

# %%
print("My age is ", a - 2)
# Out:
# My age is  40

# %%
print("My age is ', a - 2")
print("My age is ", a - 2, "and my kid's age is ", a - 41.5)
# Out:
# My age is ', a - 2
# My age is  40 and my kid's age is  0.5

# %%
print()

# %%
atom = 'helium'
print(atom[0:3])
# Out:
# hel

# %%
print(atom[3])
# Out:
# i

# %%
len(atom)
# Out:
# 6

# %%
print(Atom)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-83fcc2239283> in <module>()
# ----> 1 print(Atom)
#
# NameError: name 'Atom' is not defined

# %%
asdfasdf = 42
jklhlhlhl = "Ariel"

# %%
initial = "left"

position = initial

initial = "right"

# %%
print(initial)
print(position)
# Out:
# right
# left

# %%
print(type(52))
# Out:
# <class 'int'>

# %%
print(type(initial))
# Out:
# <class 'str'>

# %%
print(5 - 3)
# Out:
# 2

# %%
print("hello" - 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-5d75ca8f1a0a> in <module>()
# ----> 1 print("hello" - 5)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
print(5 + 3)
# Out:
# 8

# %%
print("Ariel "+ "Rokem")
# Out:
# Ariel Rokem

# %%
print("Ariel is" + str(40))
# Out:
# Ariel is40

# %%
first_name = "Ariel"

# %%
print(first_name[-4:])
# Out:
# riel

# %%
# my_float = 20.5
print(type(my_float))
# Out:
# <class 'float'>

# %%
my_int = 50
print(type(my_int))
# Out:
# <class 'int'>

# %%
a_third= 1/3.

# %%
print(a_third)
# Out:
# 0.333

# %%
my_commented_variable = 10
print(my_commented_variable)
# Out:
# 10

# %%
print(min(1, 2, 3, 4))
print(max('a', 'b', 'c', 'C', 'D'))
# Out:
# 1
# c

# %%
help(min)
# Out:
# Help on built-in function min in module builtins:
#
# min(...)
#     min(iterable, *[, default=obj, key=func]) -> value
#     min(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its smallest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the smallest argument.

# %%
giraffe = "Geoff"

# %%
first_name2 = "geoff"

# %%
giraffe.upper()
# Out:
# 'GEOFF'

# %%
asdfasdfasdf = "ariel"

# %%
print(asdfasdfasdf)
# Out:
# ariel

# %%
giraffe.lower()
# Out:
# 'geoff'

# %%
giraffe = 53

# %%
giraffe.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-159b2490bd46> in <module>()
# ----> 1 giraffe.lower()
#
# AttributeError: 'int' object has no attribute 'lower'

# %%
first_name = "Geoff"

# %%
first_name[first_name.find("G") + 1:first_name.rfind("f")]
# Out:
# 'eof'

# %%
first_name.find("G")
# Out:
# 0

# %%
first_name.find("f")
# Out:
# 3

# %%
import math

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.cos(2 * math.pi))
# Out:
# 1.0

# %%
math.log(math.e)
# Out:
# 1.0

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.6/library/math
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
#         Return the inverse hyperbolic sine of x.
#
#     atan(...)
# ...

# %%
from math import pi, sin, cos

# %%
sin(pi * 2)
# Out:
# -2.4492935982947064e-16

# %%
import numpy as np

# %%
np.sin(2 * np.pi)
# Out:
# -2.4492935982947064e-16

# %%
import math as m

# %%
m.sin(2 * m.pi)
# Out:
# -2.4492935982947064e-16

# %%
ls
# Out:
# data/  Untitled.ipynb

# %%
pwd
# Out:
# '/home/jovyan/Python'

# %%
import pandas as pd

# %%
data = pd.read_csv('data/gapminder_all.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#     continent                   country  gdpPercap_1952  gdpPercap_1957  \
# 0      Africa                   Algeria     2449.008185     3013.976023
# 1      Africa                    Angola     3520.610273     3827.940465
# 2      Africa                     Benin     1062.752200      959.601080
# 3      Africa                  Botswana      851.241141      918.232535
# 4      Africa              Burkina Faso      543.255241      617.183465
# 5      Africa                   Burundi      339.296459      379.564628
# 6      Africa                  Cameroon     1172.667655     1313.048099
# 7      Africa  Central African Republic     1071.310713     1190.844328
# 8      Africa                      Chad     1178.665927     1308.495577
# 9      Africa                   Comoros     1102.990936     1211.148548
# 10     Africa           Congo Dem. Rep.      780.542326      905.860230
# 11     Africa                Congo Rep.     2125.621418     2315.056572
# ...
